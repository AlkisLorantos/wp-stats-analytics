# %%
import sys
sys.path.append('..')
from src.db import get_all_stats, get_games, get_players
import pandas as pd
import matplotlib.pyplot as plt

# %%
stats = get_all_stats()
games = get_games()
players = get_players()

print(f"Events: {len(stats)}")
print(f"Games: {len(games)}")
print(f"Players: {len(players)}")

# %%
stats.head()

# %%
stats['type'].value_counts()
